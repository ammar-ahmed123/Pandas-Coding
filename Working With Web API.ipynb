# %%
import requests
import numpy as np
import pandas as pd
url= "https://api.github.com/repos/pandas-dev/pandas/issues"
resp= requests.get(url)
print(resp)
# Out:
# <Response [200]>

# %%
data= resp.json()
print(type(data))
print(data)
# Out:
# <class 'list'>
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29734', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29734/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29734/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29734/events', 'html_url': 'https://github.com/pandas-dev/pandas/issues/29734', 'id': 525632039, 'node_id': 'MDU6SXNzdWU1MjU2MzIwMzk=', 'number': 29734, 'title': 'Pandas dropna throwing ValueError: "Cannot convert non-finite values (NA or inf) to integer"', 'user': {'login': 'dumbledad', 'id': 110564, 'node_id': 'MDQ6VXNlcjExMDU2NA==', 'avatar_url': 'https://avatars0.githubusercontent.com/u/110564?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dumbledad', 'html_url': 'https://github.com/dumbledad', 'followers_url': 'https://api.github.com/users/dumbledad/followers', 'following_url': 'https://api.github.com/users/dumbledad/following{/other_user}', 'gists_url': 'https://api.github.com/users/dumbledad/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dumbledad/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dumbledad/subscriptions', 'organizations_url': 'https://api.github.com/users/dumbledad/orgs', 'repos_url': 'https://api.github.com/users/dumbledad/repos', 'events_url': 'https://api.github.com/users/dumbledad/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dumbledad/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2019-11-20T07:47:27Z', 'updated_at': '2019-11-20T07:58:14Z', 'closed_at': None, 'author_association': 'NONE', 'body': 'Pandas: 0.25.3\r\nPython: 3.7.4\r\n\r\nI have a data frame, and I want to remove the columns which contain only NaN values. That should be easy, because there is a Pandas DataFrame function which does exactly that—[dropna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html). Here\'s my code:\r\n\r\n<!-- language: lang-python -->\r\n\r\n    long_summary = long_summary.dropna(axis=\'columns\', how=\'all\') \r\n\r\nBut that simple line throws an exception:\r\n\r\n  > ValueError: Cannot convert non-finite values (NA or inf) to integer\r\n\r\nI cannot see how calling `dropna` would lead to this exception. Why would `dropna` try to convert any values to an integer? Is this a bug or am I misunderstanding `dropna`?\r\n\r\nI\'ll include the whole exception stack just-in-case that makes the problem clearer:\r\n\r\n<!-- language: lang-none -->\r\n\r\n    ---------------------------------------------------------------------------\r\n    ValueError                                Traceback (most recent call last)\r\n    <ipython-input-88-b4926abd4d81> in <module>\r\n    ----> 1 long_summary = long_summary.dropna(axis=\'columns\', how=\'all\')\r\n\r\n    c:\\users\\timregan\\appdata\\local\\programs\\python\\python37\\lib\\site-packages\\pandas\\core\\frame.py in dropna(self, axis, how, thresh, subset, inplace)\r\n    4860                 agg_obj = self.take(indices, axis=agg_axis)\r\n    4861 \r\n    -> 4862             count = agg_obj.count(axis=agg_axis)\r\n    4863 \r\n    4864             if thresh is not None:\r\n\r\n    c:\\users\\timregan\\appdata\\local\\programs\\python\\python37\\lib\\site-packages\\pandas\\core\\frame.py in count(self, axis, level, numeric_only)\r\n    7848                 result = Series(counts, index=frame._get_agg_axis(axis))\r\n    7849 \r\n    -> 7850         return result.astype("int64")\r\n    7851 \r\n    7852     def _count_level(self, level, axis=0, numeric_only=False):\r\n\r\n    c:\\users\\timregan\\appdata\\local\\programs\\python\\python37\\lib\\site-packages\\pandas\\core\\generic.py in astype(self, dtype, copy, errors, **kwargs)\r\n    588 ...

# %%
data_dict= data[0]
#print(data_dict["title"])
issues= pd.DataFrame(data, columns=["number","title","labels","state"])
print(issues.head())
# Out:
#    number                                              title  \
# 0   29734  Pandas dropna throwing ValueError: "Cannot con...
# 1   29733  Series.map(m: Mapping) can fail with "object i...
# 2   29732  DEPR: enforce deprecations for kwargs in facto...
# 3   29731  DEPR: change DTI.to_series keep_tz default to ...
# 4   29730       DEPR: remove reduce kwd from DataFrame.apply
#
#                                               labels state
# 0                                                 []  open
# 1                                                 []  open
# 2  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 3  [{'id': 87485152, 'node_id': 'MDU6TGFiZWw4NzQ4...  open
# 4  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
